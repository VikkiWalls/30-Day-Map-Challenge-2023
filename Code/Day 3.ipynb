# %% [markdown]
# # 30 Day Map Challenge

# %% [markdown]
# ## Day 3 - Polygons

# %% [markdown]
# Plan: Map the islands of Orkney using some of the steps from the following [tutorial](http://darribas.org/gds15/content/labs/lab_03.html)

# %% [markdown]
# Setting up the notebook:

# %%
import geopandas as gpd
import os
import pandas as pd

# %%
os.getcwd()
os.chdir("c:\\Users\\vicks\\OneDrive\\Data Science (not uni)\\Data-Sources\\os boundary data\\Data\\GB")

# %%
wind = gpd.read_file("scotland_and_wales_const_region.shp")

# %%
print(wind.crs)
# Out:
# EPSG:27700

# %%
ax1 = wind.plot(figsize=(50,50), cmap='plasma', alpha=1, legend=True)
#land.plot(figsize=(50,50), color = 'cyan', ax = ax1, alpha = 0.3)
ax1.set_axis_off()
