# %% [markdown]
# # 30 Day Map Challenge

# %% [markdown]
# ## Day 9 - Hexagons

# %% [markdown]
# Plan: Recycling day 4 data to build a hexbin map

# %%
import os
import pandas as pd
import plotly.figure_factory as ff
import plotly.express as px

# %matplotlib inline
px.defaults.width = 1070
px.defaults.height = 600

# %% [markdown]
# Setting the working directory

# %%
os.getcwd()
os.chdir("c:\\Users\\vicks\\OneDrive\\Data Science (not uni)\\Portfolio\\30 Day Map Challenge\\2023 data\\Day 4")

# %% [markdown]
# Setting my personal mapbox token to access the mapbox tools

# %%
px.set_mapbox_access_token(open("mapboxtoken.txt").read())

# %% [markdown]
# Importing the [data](https://www.gbif.org/occurrence/search?offset=80&dataset_key=0a0d4ca1-5bfd-4594-9d51-40b972308bf5&has_coordinate=true&has_geospatial_issue=false&geometry=POLYGON((-21.64723%2050.24421,14.64723%2050.24421,14.64723%2064.75579,-21.64723%2064.75579,-21.64723%2050.24421))&occurrence_status=present)

# %%
Shootings = pd.read_csv("2023 mass shootings USA.csv")
Shootings.head()
# Out:
#         Lat       Long
# 0  17.98413  -66.11377
# 1  18.44653  -66.13557
# 2  18.46705  -66.11845
# 3  21.42059 -158.17427
# 4  25.46872  -80.47755

# %% [markdown]
# Building the hexbin map

# %%
fig = ff.create_hexbin_mapbox(
    data_frame=Shootings, lat="Lat", lon="Long",
    nx_hexagon=20, opacity=0.5, labels={"color": "Shootings"},
    zoom = 2.5,
    color_continuous_scale="Reds",
    min_count=1,
    show_original_data=True,
    original_data_marker=dict(size=4, opacity=0.6, color="red")
)
fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0}, mapbox_style="mapbox://styles/mapbox/dark-v10", paper_bgcolor = 'rgba(0,0,0,0.85)')
fig.update_coloraxes(colorbar_bgcolor='rgba(0,0,0,0.85)', colorbar_xpad=10, colorbar_tickfont_color='red',
                        colorbar_title_font_color='red', cmin=0)
fig.show()

# %%
fig.write_html("hexplot.html")
